# %%
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline  
import json

# %%
data_path = 'cocotalk.h5'
f = h5py.File(data_path, "r")
json_file_path = 'cocotalk.json'
json_file = json.load(open(json_file_path, 'r'))

# %%
image = f.get('images')[3000]
img_id = f.get('image')
print(image.shape)
json_file['images'][3000]['id']
# Out:
# (3, 256, 256)
# 27408

# %%
plt.imshow(image.transpose(1,2,0))
plt.show()
